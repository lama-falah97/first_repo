# %%
#home-task , upload it in git
print ("Welcome to Tempreture Converter from C to F")
c_temp = input ("Enter the tempreture in Celsius: ")
f_temp = ( int(c_temp) * 1.8 ) + 32
print("Fahrenheit temp is ", f_temp)
# Out:
# Welcome to Tempreture Converter from C to F
# Enter the tempreture in Celsius: 89
# Fahrenheit temp is  192.20000000000002
